# %%
# %load_ext autoreload
# %autoreload 2

# %%
from envs.CarRacing import CarRacing
from networks.CQNet import CQNetImage
from networks.MuNet  import MuNetImage
from memory.RewardMemory import Memory
#from memory.TorchMemory import Memory
from tqdm.notebook import tqdm
import numpy as np
from networks.utils import *
import torch
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Create environment
env = CarRacing()

# Create network
critic = CQNetImage(input_channels=3, hidden_dim=128, action_dim=3).to(device)
actor = MuNetImage(input_channels=3, hidden_dim=128, action_dim=3).to(device)

critic_copy = CQNetImage(input_channels=3, hidden_dim=128, action_dim=3).to(device)
actor_copy = MuNetImage(input_channels=3, hidden_dim=128, action_dim=3).to(device)
critic_copy.copyfrom(critic)
actor_copy.copyfrom(actor)

# Create replay memory
memory = Memory(3, env.states, 3, 30000)

epsilon = 1.0
espilon_decay = 0.97
epsilon_min = 0.05

gamma = 0.99
batch_size = 256

sigma = 0.25

ddpg_rewards_per_ep = {} # store rewards for each episode

# Update target netwoks
update_target = 200
update_counter = 0

for e in range(200):
    # Reset environment
    state = env.reset()
    ep_reward = 0
    cont = 0
    
    for t in range(1000):
        action = actor(state).cpu().data.numpy()
        action = np.random.normal(loc=action, scale=sigma).reshape(3)

        # Step environment
        obs, r, terminal, truncated, info = env.step(2*action)

        if action[1] < action[2]:
            r -= 5
        if action[1] > 0.5:
            r += 10
        if action[2] > 0.5:
            r -= 10
        if action[2] < 0.2:
            r += 2 

        ep_reward += r
        memory.add(state[0, 2, :, :], action, r, terminal)
        
        # If at least 1000 transitions in memory, sample minibatch and learn (exercise 2.3)
        if len(memory) >= batch_size:
            minibatch = memory.sample(batch_size)
            states, actions, rewards, next_states, terminals = minibatch
            

            # Compute target values for critic network
            next_actions = actor_copy(next_states)
            #print(next_states.shape)
            #print(next_actions.shape)
            next_q_values = critic_copy(next_states, next_actions)
            targets = rewards + gamma * next_q_values * (1 - terminals)

            # Update critic and actor networks
            critic.update(states, actions, targets, cpu=False)
            actor.update(states, critic)

            # Update target networks if necessary
            update_counter += 1
            if update_counter >= update_target:
                critic_copy.copyfrom(critic)
                actor_copy.copyfrom(actor)
                update_counter = 0

        state = obs

        if terminal or truncated:
            break
        
        cont += 1
    
    ddpg_rewards_per_ep[e] = [ep_reward, cont]

    if epsilon > epsilon_min:
        epsilon *= espilon_decay

# Close environment
# env.plotnetwork(actor, critic)
env.close()
# Out:
# tensor([[-0.0459, -0.0024,  0.0263]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0456, -0.0024,  0.0260]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0019,  0.0257]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0256]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0013,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0011,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0016,  0.0259]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0256]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0256]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0016,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0016,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0257]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0016,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0258]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0259]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0259]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0260]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0014,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0460, -0.0016,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0016,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0016,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0260]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0260]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0459, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0016,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0016,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0263]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0263]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0263]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0015,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0458, -0.0014,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0261]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0457, -0.0014,  0.0262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25452\91244252.py in <module>
#      40
#      41         # Step environment
# ---> 42         obs, r, terminal, truncated, info = env.step(2*action)
#      43
#      44         if action[1] < action[2]:
#
# f:\GitHub\CarRacing-V2\envs\CarRacing.py in step(self, u, cpu)
#     108         u = np.array(u)
#     109         #print(u)
# --> 110         img_rgb, r, terminal, truncated, info = Environment.step(self, u)
#     111         #print(img_rgb, r, terminal, truncated, info)
#     112
#
# f:\GitHub\CarRacing-V2\envs\CarRacing.py in step(self, u)
#      34            extra information.
#      35         """
# ---> 36         observation, reward, terminal, truncated, info = self.env.step(u)
#      37
#      38         return (observation, reward, terminal, truncated, info)
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\wrappers\time_limit.py in step(self, action)
#      55
#      56         """
# ---> 57         observation, reward, terminated, truncated, info = self.env.step(action)
#      58         self._elapsed_steps += 1
#      59
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\wrappers\order_enforcing.py in step(self, action)
#      54         if not self._has_reset:
#      55             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56         return self.env.step(action)
#      57
#      58     def reset(self, **kwargs):
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\wrappers\env_checker.py in step(self, action)
#      49             return env_step_passive_checker(self.env, action)
#      50         else:
# ---> 51             return self.env.step(action)
#      52
#      53     def reset(self, **kwargs):
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\envs\box2d\car_racing.py in step(self, action)
#     574
#     575         if self.render_mode == "human":
# --> 576             self.render()
#     577         return self.state, step_reward, terminated, truncated, {}
#     578
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\envs\box2d\car_racing.py in render(self)
#     587             return
#     588         else:
# --> 589             return self._render(self.render_mode)
#     590
#     591     def _render(self, mode: str):
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\envs\box2d\car_racing.py in _render(self, mode)
#     615         trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
#     616
# --> 617         self._render_road(zoom, trans, angle)
#     618         self.car.draw(
#     619             self.surf,
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\envs\box2d\car_racing.py in _render_road(self, zoom, translation, angle)
#     685             poly = [(p[0], p[1]) for p in poly]
#     686             color = [int(c) for c in color]
# --> 687             self._draw_colored_polygon(self.surf, poly, color, zoom, translation, angle)
#     688
#     689     def _render_indicators(self, W, H):
#
# c:\Users\jpkqv\anaconda3\envs\rlga\lib\site-packages\gymnasium\envs\box2d\car_racing.py in _draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     772             for coord in poly
#     773         ):
# --> 774             gfxdraw.aapolygon(self.surf, poly, color)
#     775             gfxdraw.filled_polygon(self.surf, poly, color)
#     776
#
# KeyboardInterrupt:
